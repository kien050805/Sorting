# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = {"array_length": [10, 100, 1000, 10000, 100000],
        "insertion_sort": [1, 5, 387, 34551, 3436440],
        "merge_sort": [1, 8, 112, 1382, 16374],
        "quick_sort": [1, 5, 83, 1118, 13514],
        "randomized_quick_sort": [53, 568, 5795, 57818, 579853]}

df = pd.DataFrame(data)
df = df.set_index("array_length")
df.head(10)
# Out:
#               insertion_sort  merge_sort  quick_sort  randomized_quick_sort
# array_length
# 10                         1           1           1                     53
# 100                        5           8           5                    568
# 1000                     387         112          83                   5795
# 10000                  34551        1382        1118                  57818
# 100000               3436440       16374       13514                 579853

# %%
sns.set(style="darkgrid")
tips = sns.load_dataset("tips")
color = sns.color_palette()[2]
f, ax = plt.subplots(figsize=(7, 7))
ax.set(xscale="log", yscale="log")
sns.lineplot(data=df)
# Out:
# <Axes: xlabel='array_length'>
